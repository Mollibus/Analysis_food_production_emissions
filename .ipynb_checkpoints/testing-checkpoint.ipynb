# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns
pd.set_option("display.max_columns",100)

# %%
df = pd.read_csv("Food_Production.csv")
df1 = pd.read_csv("ghg-kcal-poore.csv")
df2 = pd.read_csv("land-use-kcal-poore.csv")
df3 = pd.read_csv("land-use-per-kg-poore.csv")
shared_emissions = pd.read_csv("share-global-food-emissions.csv")

# %%
for n in df1["Entity"]: 
    if not n in sorted(df3["Entity"]): 
        print(n)
# Out:
# Olive Oil
# Palm Oil
# Rapeseed Oil
# Sunflower Oil

# %%
df3["Entity"]
# Out:
# 0                  Apples
# 1                 Bananas
# 2           Barley (Beer)
# 3        Beef (beef herd)
# 4       Beef (dairy herd)
# 5              Beet Sugar
# 6        Berries & Grapes
# 7               Brassicas
# 8              Cane Sugar
# 9                 Cassava
# 10                 Cheese
# 11           Citrus Fruit
# 12                 Coffee
# 13         Dark Chocolate
# 14                   Eggs
# 15          Fish (farmed)
# 16             Groundnuts
# 17          Lamb & Mutton
# 18           Maize (Meal)
# 19                   Milk
# 20                   Nuts
# 21                Oatmeal
# 22         Onions & Leeks
# 23            Other Fruit
# 24           Other Pulses
# 25       Other Vegetables
# 26                   Peas
# 27               Pig Meat
# 28               Potatoes
# 29           Poultry Meat
# 30        Prawns (farmed)
# 31                   Rice
# 32        Root Vegetables
# 33                Soymilk
# 34                   Tofu
# ...

# %%
df1 = df1.merge(df2, on='Entity' ).drop("Code_x")
df1 = df1.merge(df3, on='Entity' )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18120/613406302.py in <module>
# ----> 1 df1 = df1.merge(df2, on='Entity' ).drop("Code_x")
#       2 df1 = df1.merge(df3, on='Entity' )
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df1
# Out:
#                  Entity  Code  Year  \
# 0                Apples   NaN  2010
# 1               Bananas   NaN  2010
# 2         Barley (Beer)   NaN  2010
# 3      Beef (beef herd)   NaN  2010
# 4     Beef (dairy herd)   NaN  2010
# 5            Beet Sugar   NaN  2010
# 6      Berries & Grapes   NaN  2010
# 7             Brassicas   NaN  2010
# 8            Cane Sugar   NaN  2010
# 9               Cassava   NaN  2010
# 10               Cheese   NaN  2010
# 11         Citrus Fruit   NaN  2010
# 12               Coffee   NaN  2010
# 13       Dark Chocolate   NaN  2010
# 14                 Eggs   NaN  2010
# 15        Fish (farmed)   NaN  2010
# 16           Groundnuts   NaN  2010
# 17        Lamb & Mutton   NaN  2010
# 18         Maize (Meal)   NaN  2010
# 19                 Milk   NaN  2010
# 20                 Nuts   NaN  2010
# 21              Oatmeal   NaN  2010
# 22            Olive Oil   NaN  2010
# 23       Onions & Leeks   NaN  2010
# 24         Other Pulses   NaN  2010
# ...

# %%
dfinal = df.merge(f1, left_on='Food product', right_on='Entity')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18120/3602496251.py in <module>
# ----> 1 dfinal = df.merge(f1, left_on='Food product', right_on='Entity')
#
# NameError: name 'f1' is not defined

# %%
shared_emissions
# Out:
#            Entity Code  Year  Share of global food emissions
# 0     Afghanistan  AFG  1990                        0.064511
# 1     Afghanistan  AFG  1991                        0.065742
# 2     Afghanistan  AFG  1992                        0.066519
# 3     Afghanistan  AFG  1993                        0.067725
# 4     Afghanistan  AFG  1994                        0.068905
# ...           ...  ...   ...                             ...
# 5845     Zimbabwe  ZWE  2011                        0.315804
# 5846     Zimbabwe  ZWE  2012                        0.314929
# 5847     Zimbabwe  ZWE  2013                        0.314927
# 5848     Zimbabwe  ZWE  2014                        0.294565
# 5849     Zimbabwe  ZWE  2015                        0.288842
#
# [5850 rows x 4 columns]

# %%
shared_emissions.Year.max()
# Out:
# 2015

# %%
largest = shared_emissions.drop(shared_emissions[(shared_emissions["Entity"]=="Developing" )| (shared_emissions["Entity"]=="Industrialized")].index)
largest = largest.groupby("Entity").sum().sort_values("Share of global food emissions",ascending=False).head(10)
largest_list = largest.groupby("Entity").sum().sort_values("Share of global food emissions",ascending=False).head(10).index

# %%
largest
# Out:
#                 Year  Share of global food emissions
# Entity
# China          52065                      302.730138
# Brazil         52065                      252.899680
# Indonesia      52065                      228.509281
# United States  52065                      217.443716
# India          52065                      144.529022
# Russia         52065                       84.024409
# Zambia         52065                       65.433966
# Sudan          52065                       55.522306
# Argentina      52065                       50.813928
# Canada         52065                       45.943544

# %%
subset = shared_emissions[shared_emissions["Entity"].isin(largest)]

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x="Year",y="Share of global food emissions", hue= "Entity",data=subset)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Share of global food emissions'>

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18120/400337849.py in <module>
# ----> 1 largest[largest["Entity"]=="Indonesia"]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    4602         if is_scalar(key):
#    4603             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4604             return getitem(key)
#    4605
#    4606         if isinstance(key, slice):
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
